# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (3.6.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (0.2.0)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn-extra) (1.2.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn-extra) (1.9.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn-extra) (1.23.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\posgraduacao\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as sch
from scipy.cluster import hierarchy

# %%
pokemons = pd.read_csv('gen_9.csv')

# %%
pokemons.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0              Pokémon    H    A    B    C    D    S  Total
# 0             0             Koraidon  100  135  115   85  100  135    670
# 1             1             Miraidon  100   85  100  135  115  135    670
# 2             2              Slaking  150  160  100   95   65  100    670
# 3             3  Palafin (Hero Form)  100  160   97  106   87  100    650
# 4             4             Garchomp  108  130   95   80   85  102    600
# ..          ...                  ...  ...  ...  ...  ...  ...  ...    ...
# 417         417                Ralts   28   25   25   45   35   40    198
# 418         418            Kricketot   37   25   41   25   41   25    194
# 419         419              Azurill   50   20   40   20   40   20    190
# 420         420                 Snom   30   25   35   45   30   20    185
# 421         421              Sunkern   30   30   30   30   30   30    180
#
# [422 rows x 9 columns]>

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  422 non-null    int64
#  1   Pokémon     422 non-null    object
#  2   H           422 non-null    int64
#  3   A           422 non-null    int64
#  4   B           422 non-null    int64
#  5   C           422 non-null    int64
#  6   D           422 non-null    int64
#  7   S           422 non-null    int64
#  8   Total       422 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 29.8+ KB

# %% [markdown]
# # Checando as Variáveis

# %%
sb.pairplot(pokemons)

# %%
pokemons.hist(figsize = (20,25))
# Out:
# array([[<AxesSubplot: title={'center': 'Unnamed: 0'}>,
#         <AxesSubplot: title={'center': 'H'}>,
#         <AxesSubplot: title={'center': 'A'}>],
#        [<AxesSubplot: title={'center': 'B'}>,
#         <AxesSubplot: title={'center': 'C'}>,
#         <AxesSubplot: title={'center': 'D'}>],
#        [<AxesSubplot: title={'center': 'S'}>,
#         <AxesSubplot: title={'center': 'Total'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
corr = pokemons.corr()
f, ax = plt.subplots(figsize=(12, 12))
sb.heatmap(corr, square=True, linewidths=.5, annot=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1748\3969723277.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = pokemons.corr()
# <AxesSubplot: >
